# %%
import unittest
import reader, kb, core

class UnitTests(unittest.TestCase):

    @classmethod
    def setUpClass(cls):
        cls.sExistentials = []
        cls.sFeatures = []
        cls.qExistentials = []
        cls.qFeatures = []
        cls.qCounts = []
        cls.Commands = []

        cls.sExistentials.append('There are two rooms on the first floor')
        cls.sExistentials.append('There is a wooden table in one of the rooms')
        cls.sExistentials.append('There is a metal table in the other')
        cls.sExistentials.append('There are ten red blocks on the wooden table')
        cls.sExistentials.append('There are two green blocks')
        cls.sExistentials.append('There is a box on the metal table')
        cls.sExistentials.append('There is a box on Table0')
        cls.sExistentials.append('There are three big red blocks on the wooden table on the first floor')

        cls.sFeatures.append('Three of the red blocks are cubes')
        cls.sFeatures.append('The green blocks are pyramids')
        cls.sFeatures.append('The boxes are big')
        cls.sFeatures.append('The pyramids are on the metal table')

        cls.Commands.append('Move Block2 from the table onto the green block')
        cls.Commands.append('Put the red block on the green block')

        cls.qFeatures.append('Is the red block big')
        cls.qFeatures.append('What color are the blocks on the table')
        cls.qFeatures.append('Where is the red block')
        cls.qFeatures.append('Where is the red block')

        cls.qExistentials.append('Are there three red blocks on the table')
        cls.qCounts.append('How many red blocks are on the table')

        cls.qCounts.append('How many red blocks are on the table')

        facts, rules = reader.read_tokenize("initial_kb.txt")

        # Building world: facts

        for fact in facts:
            kb.Assert(kb.statement(fact))

        # Building world: rules

        for new_rule in rules:
            kb.Assert_Rule(kb.rule(new_rule[0], new_rule[1]))

        # Build the world

        core.buildFOPC('There are two rooms on the first floor')
        core.buildFOPC('There is a wooden table in one of the rooms')
        core.buildFOPC('There is a metal table in the other')
        core.buildFOPC('There are ten red blocks on the wooden table')
        core.buildFOPC('There are two green blocks')
        core.buildFOPC('There is a box on the metal table')
        core.buildFOPC('There is a box on Table0')

    def test01_01(self):
        core.buildFOPC('Three of the red blocks are cubes')
        self.assertTrue(kb.betterAsk([['inst', 'Block0', 'cube']]))

    def test01_02(self):
        core.buildFOPC('Three of the red blocks are cubes')
        self.assertTrue(kb.betterAsk([['inst', 'Block1', 'cube']]))

    def test01_03(self):
        core.buildFOPC('Three of the red blocks are cubes')
        self.assertTrue(kb.betterAsk([['inst', 'Block2', 'cube']]))

    def test02_01(self):
        core.buildFOPC('The green blocks are pyramids')
        self.assertTrue(kb.betterAsk([['inst', 'Block10', 'pyramid']]))

    def test02_02(self):
        core.buildFOPC('The green blocks are pyramids')
        self.assertTrue(kb.betterAsk([['inst', 'Block11', 'pyramid']]))

    def test03_01(self):
        core.buildFOPC('The boxes are big')
        self.assertTrue(kb.betterAsk([['size', 'Box0', 'big']]))

    def test03_02(self):
        core.buildFOPC('The boxes are big')
        self.assertTrue(kb.betterAsk([['size', 'Box1', 'big']]))

    def test04_01(self):
        core.buildFOPC('The pyramids are on the metal table')
        self.assertTrue(kb.betterAsk([['on', 'Block10', 'Table1']]))

    def test04_02(self):
        core.buildFOPC('The pyramids are on the metal table')
        self.assertTrue(kb.betterAsk([['on', 'Block11', 'Table1']]))
        
    if __name__ == '__main__':
        unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# 	Infering refined rule: Rule 2: When <(isa object ?z)> Assert (isa table ?z)
# 	Infering refined rule: Rule 4: When <(isa object ?z)> Assert (isa chair ?z)
# 	Infering refined rule: Rule 7: When <(isa object ?z)> Assert (isa box ?z)
#
# Processing sentence: There are two rooms on the first floor
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: are 	Children: []
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['there', 'room', 'on']
# two	 	STEM: two 	POS: NUM 	REL: nummod 	HEADER: rooms 	Children: []
# rooms	 	STEM: room 	POS: NOUN 	REL: attr 	HEADER: are 	Children: ['two']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: are 	Children: ['floor']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: floor 	Children: []
# first	 	STEM: first 	POS: ADJ 	REL: amod 	HEADER: floor 	Children: []
# floor	 	STEM: floor 	POS: NOUN 	REL: pobj 	HEADER: on 	Children: ['the', 'first']
#
# Sentence is an instance of: S:Existential
#
# ROOT: are
# Primary Object: rooms
#
# Resolving object: room
# Referenced object is being defined in sentence
# Building new object: room
# Count: 2
# New Names: ['Room0', 'Room1']
# Checking features to modify ['Room0', 'Room1']
# Checking pObjs of room to modify room
# Done with prepositions for: room
# Done building: room
# Returning ['Room0', 'Room1']
# Checking pObjs of be to modify room
#   vPrep: on Feature: floor
#
# Resolving object: floor
# Building concept to search KB for floor
# Looking for an ?x that matches:
#       ['inst', '?x', 'floor']
#       ['level', '?x', 'first']
# Found reference in KB: Floor1
# Returning ['Floor1']
# floor resolved to Floor1
# Done with prepositions for: room
#
# Long Term Memory Category: {'room': {'referenced': ['Room0', 'Room1']}, 'floor': {'referenced': ['Floor1']}}
#
# Processing sentence: There is a wooden table in one of the rooms
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: is 	Children: []
# is	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: is 	Children: ['there', 'table']
# a	 	STEM: a 	POS: DET 	REL: det 	HEADER: table 	Children: []
# wooden	 	STEM: wooden 	POS: ADJ 	REL: amod 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: attr 	HEADER: is 	Children: ['a', 'wooden', 'in']
# in	 	STEM: in 	POS: ADP 	REL: prep 	HEADER: table 	Children: ['one']
# one	 	STEM: one 	POS: NUM 	REL: pobj 	HEADER: in 	Children: ['of']
# of	 	STEM: of 	POS: ADP 	REL: prep 	HEADER: one 	Children: ['room']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: rooms 	Children: []
# rooms	 	STEM: room 	POS: NOUN 	REL: pobj 	HEADER: of 	Children: ['the']
#
# Sentence is an instance of: S:Existential
#
# ROOT: is
# Primary Object: table
#
# Resolving object: table
# Referenced object is being defined in sentence
# Building new object: table
# Count: 1
# New Names: ['Table0']
# Checking features to modify ['Table0']
# Found wooden
# Checking pObjs of table to modify table
#   vPrep: in Feature: one
#
# Resolving object: one
# Building concept to search KB for one 'room'
# Looking for an ?x that matches:
#       ['inst', '?x', 'room']
# Found references in KB:
# Selecting a subset from 2 elements
# Category: {'room': {'referenced': ['Room0', 'Room1']}, 'floor': {'referenced': ['Floor1']}}
# {'referenced': ['Room0', 'Room1']}
# Selected ['Room0']
# Returning ['Room0']
# one resolved to Room0
# Done with prepositions for: table
# Done building: table
# Returning ['Table0']
# Checking pObjs of be to modify table
# Done with prepositions for: table
#
# Long Term Memory Category: {'room': {'referenced': ['Room0'], 'remaining': ['Room1']}, 'table': {'referenced': ['Table0']}}
#
# Processing sentence: There is a metal table in the other
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: is 	Children: []
# is	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: is 	Children: ['there', 'table']
# a	 	STEM: a 	POS: DET 	REL: det 	HEADER: table 	Children: []
# metal	 	STEM: metal 	POS: NOUN 	REL: compound 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: attr 	HEADER: is 	Children: ['a', 'metal', 'in']
# in	 	STEM: in 	POS: ADP 	REL: prep 	HEADER: table 	Children: ['other']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: other 	Children: []
# other	 	STEM: other 	POS: ADJ 	REL: pobj 	HEADER: in 	Children: ['the']
#
# Sentence is an instance of: S:Existential
#
# ROOT: is
# Primary Object: table
#
# Resolving object: table
# Referenced object is being defined in sentence
# Building new object: table
# Count: 1
# New Names: ['Table1']
# Checking features to modify ['Table1']
# Found metal
# Checking pObjs of table to modify table
#   vPrep: in Feature: other
#
# Resolving object: other
# Returning ['Room1']
# other resolved to Room1
# Done with prepositions for: table
# Done building: table
# Returning ['Table1']
# Checking pObjs of be to modify table
# Done with prepositions for: table
#
# Long Term Memory Category: {'table': {'referenced': ['Table1']}}
#
# Processing sentence: There are ten red blocks on the wooden table
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: are 	Children: []
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['there', 'block']
# ten	 	STEM: ten 	POS: NUM 	REL: nummod 	HEADER: blocks 	Children: []
# red	 	STEM: red 	POS: ADJ 	REL: amod 	HEADER: blocks 	Children: []
# blocks	 	STEM: block 	POS: NOUN 	REL: attr 	HEADER: are 	Children: ['ten', 'red', 'on']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: blocks 	Children: ['table']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: table 	Children: []
# wooden	 	STEM: wooden 	POS: ADJ 	REL: amod 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: pobj 	HEADER: on 	Children: ['the', 'wooden']
#
# Sentence is an instance of: S:Existential
#
# ROOT: are
# Primary Object: blocks
#
# Resolving object: block
# Referenced object is being defined in sentence
# Building new object: block
# Count: 10
# New Names: ['Block0', 'Block1', 'Block2', 'Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9']
# Checking features to modify ['Block0', 'Block1', 'Block2', 'Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9']
# Found red
# Checking pObjs of block to modify block
#   vPrep: on Feature: table
#
# Resolving object: table
# Building concept to search KB for table
# Looking for an ?x that matches:
#       ['inst', '?x', 'table']
#       ['material', '?x', 'wooden']
# Found reference in KB: Table0
# Returning ['Table0']
# table resolved to Table0
# Done with prepositions for: block
# Done building: block
# Returning ['Block0', 'Block1', 'Block2', 'Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9']
# Checking pObjs of be to modify block
# Done with prepositions for: block
#
# Long Term Memory Category: {'table': {'referenced': ['Table0']}, 'block': {'referenced': ['Block0', 'Block1', 'Block2', 'Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9']}}
#
# Processing sentence: There are two green blocks
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: are 	Children: []
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['there', 'block']
# two	 	STEM: two 	POS: NUM 	REL: nummod 	HEADER: blocks 	Children: []
# green	 	STEM: green 	POS: ADJ 	REL: amod 	HEADER: blocks 	Children: []
# blocks	 	STEM: block 	POS: NOUN 	REL: attr 	HEADER: are 	Children: ['two', 'green']
#
# Sentence is an instance of: S:Existential
#
# ROOT: are
# Primary Object: blocks
#
# Resolving object: block
# Referenced object is being defined in sentence
# Building new object: block
# Count: 2
# New Names: ['Block10', 'Block11']
# Checking features to modify ['Block10', 'Block11']
# Found green
# Checking pObjs of block to modify block
# Done with prepositions for: block
# Done building: block
# Returning ['Block10', 'Block11']
# Checking pObjs of be to modify block
# Done with prepositions for: block
#
# Long Term Memory Category: {'block': {'referenced': ['Block10', 'Block11']}}
#
# Processing sentence: There is a box on the metal table
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: is 	Children: []
# is	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: is 	Children: ['there', 'box']
# a	 	STEM: a 	POS: DET 	REL: det 	HEADER: box 	Children: []
# box	 	STEM: box 	POS: NOUN 	REL: attr 	HEADER: is 	Children: ['a', 'on']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: box 	Children: ['table']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: table 	Children: []
# metal	 	STEM: metal 	POS: NOUN 	REL: compound 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: pobj 	HEADER: on 	Children: ['the', 'metal']
#
# Sentence is an instance of: S:Existential
#
# ROOT: is
# Primary Object: box
#
# Resolving object: box
# Referenced object is being defined in sentence
# Building new object: box
# Count: 1
# New Names: ['Box0']
# Checking features to modify ['Box0']
# Checking pObjs of box to modify box
#   vPrep: on Feature: table
#
# Resolving object: table
# Building concept to search KB for table
# Looking for an ?x that matches:
#       ['inst', '?x', 'table']
#       ['material', '?x', 'metal']
# Found reference in KB: Table1
# Returning ['Table1']
# table resolved to Table1
# Done with prepositions for: box
# Done building: box
# Returning ['Box0']
# Checking pObjs of be to modify box
# Done with prepositions for: box
#
# Long Term Memory Category: {'table': {'referenced': ['Table1']}, 'box': {'referenced': ['Box0']}}
#
# Processing sentence: There is a box on Table0
#
#
# ****************************
#
# There	 	STEM: there 	POS: ADV 	REL: expl 	HEADER: is 	Children: []
# is	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: is 	Children: ['there', 'box']
# a	 	STEM: a 	POS: DET 	REL: det 	HEADER: box 	Children: []
# box	 	STEM: box 	POS: NOUN 	REL: attr 	HEADER: is 	Children: ['a', 'on']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: box 	Children: ['table0']
# Table0	 	STEM: table0 	POS: PROPN 	REL: pobj 	HEADER: on 	Children: []
#
# Sentence is an instance of: S:Existential
#
# ROOT: is
# Primary Object: box
#
# Resolving object: box
# Referenced object is being defined in sentence
# Building new object: box
# Count: 1
# New Names: ['Box1']
# Checking features to modify ['Box1']
# Checking pObjs of box to modify box
#   vPrep: on Feature: Table0
#
# Resolving object: table0
# Table0  is a proper name.
# Returning Table0
# Table0 resolved to Table0
# Done with prepositions for: box
# Done building: box
# Returning ['Box1']
# Checking pObjs of be to modify box
# Done with prepositions for: box
#
# Long Term Memory Category: {False: {'referenced': ['Table0']}, 'box': {'referenced': ['Box1']}}
#
# Processing sentence: Three of the red blocks are cubes
#
#
# ****************************
#
# Three	 	STEM: three 	POS: NUM 	REL: nsubj 	HEADER: are 	Children: ['of']
# of	 	STEM: of 	POS: ADP 	REL: prep 	HEADER: Three 	Children: ['block']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: blocks 	Children: []
# red	 	STEM: red 	POS: ADJ 	REL: amod 	HEADER: blocks 	Children: []
# blocks	 	STEM: block 	POS: NOUN 	REL: pobj 	HEADER: of 	Children: ['the', 'red']
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['three', 'cube']
# cubes	 	STEM: cube 	POS: NOUN 	REL: attr 	HEADER: are 	Children: []
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: three
# Building concept to search KB for three 'block'
# Looking for an ?x that matches:
#       ['inst', '?x', 'block']
# Found references in KB:
# Selecting a subset from 12 elements
# Category: {False: {'referenced': ['Table0']}, 'box': {'referenced': ['Box1']}}
# Selected ['Block0', 'Block1', 'Block2']
# Returning ['Block0', 'Block1', 'Block2']
# Checking pObjs of be to modify three
# Done with prepositions for: three
# Checking features to modify ['Block0', 'Block1', 'Block2']
# Checking features to define ['Block0', 'Block1', 'Block2']
# Found defining feature cubes
#
# Long Term Memory Category: {'block': {'referenced': ['Block0', 'Block1', 'Block2'], 'remaining': ['Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9', 'Block10', 'Block11']}}
# .
# Processing sentence: Three of the red blocks are cubes
#
#
# ****************************
#
# Three	 	STEM: three 	POS: NUM 	REL: nsubj 	HEADER: are 	Children: ['of']
# of	 	STEM: of 	POS: ADP 	REL: prep 	HEADER: Three 	Children: ['block']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: blocks 	Children: []
# red	 	STEM: red 	POS: ADJ 	REL: amod 	HEADER: blocks 	Children: []
# blocks	 	STEM: block 	POS: NOUN 	REL: pobj 	HEADER: of 	Children: ['the', 'red']
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['three', 'cube']
# cubes	 	STEM: cube 	POS: NOUN 	REL: attr 	HEADER: are 	Children: []
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: three
# Building concept to search KB for three 'block'
# Looking for an ?x that matches:
#       ['inst', '?x', 'block']
# Found references in KB:
# Selecting a subset from 12 elements
# Category: {'block': {'referenced': ['Block0', 'Block1', 'Block2'], 'remaining': ['Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9', 'Block10', 'Block11']}}
# {'referenced': ['Block0', 'Block1', 'Block2'], 'remaining': ['Block3', 'Block4', 'Block5', 'Block6', 'Block7', 'Block8', 'Block9', 'Block10', 'Block11']}
# Filtering off of last statement
# Selected ['Block3', 'Block4', 'Block5']
# Returning ['Block3', 'Block4', 'Block5']
# Checking pObjs of be to modify three
# Done with prepositions for: three
# Checking features to modify ['Block3', 'Block4', 'Block5']
# Checking features to define ['Block3', 'Block4', 'Block5']
# Found defining feature cubes
#
# Long Term Memory Category: {'block': {'referenced': ['Block3', 'Block4', 'Block5'], 'remaining': ['Block6', 'Block7', 'Block8', 'Block9', 'Block10', 'Block11']}}
# .
# Processing sentence: Three of the red blocks are cubes
#
#
# ****************************
#
# Three	 	STEM: three 	POS: NUM 	REL: nsubj 	HEADER: are 	Children: ['of']
# of	 	STEM: of 	POS: ADP 	REL: prep 	HEADER: Three 	Children: ['block']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: blocks 	Children: []
# red	 	STEM: red 	POS: ADJ 	REL: amod 	HEADER: blocks 	Children: []
# blocks	 	STEM: block	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['box', 'big']
# big	 	STEM: big 	POS: ADJ 	REL: acomp 	HEADER: are 	Children: []
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: box
# Building concept to search KB for box
# Looking for an ?x that matches:
#       ['inst', '?x', 'box']
# Found reference in KB:
# Returning ['Box0', 'Box1']
# Checking pObjs of be to modify box
# Done with prepositions for: box
# Checking features to modify ['Box0', 'Box1']
# Found big
# Checking features to define ['Box0', 'Box1']
#
# Long Term Memory Category: {'box': {'referenced': ['Box0', 'Box1']}}
# .
# Processing sentence: The boxes are big
#
#
# ****************************
#
# The	 	STEM: the 	POS: DET 	REL: det 	HEADER: boxes 	Children: []
# boxes	 	STEM: box 	POS: NOUN 	REL: nsubj 	HEADER: are 	Children: ['the']
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['box', 'big']
# big	 	STEM: big 	POS: ADJ 	REL: acomp 	HEADER: are 	Children: []
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: box
# Building concept to search KB for box
# Looking for an ?x that matches:
#       ['inst', '?x', 'box']
# Found reference in KB:
# Returning ['Box0', 'Box1']
# Checking pObjs of be to modify box
# Done with prepositions for: box
# Checking features to modify ['Box0', 'Box1']
# Found big
# Checking features to define ['Box0', 'Box1']
#
# Long Term Memory Category: {'box': {'referenced': ['Box0', 'Box1']}}
# .
# Processing sentence: The pyramids are on the metal table
#
#
# ****************************
#
# The	 	STEM: the 	POS: DET 	REL: det 	HEADER: pyramids 	Children: []
# pyramids 	STEM: pyramid 	POS: NOUN 	REL: nsubj 	HEADER: are 	Children: ['the']
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['pyramid', 'on']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: are 	Children: ['table']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: table 	Children: []
# metal	 	STEM: metal 	POS: NOUN 	REL: compound 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: pobj 	HEADER: on 	Children: ['the', 'metal']
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: pyramid
# Building concept to search KB for pyramid
# Looking for an ?x that matches:
#       ['inst', '?x', 'pyramid']
# Found reference in KB:
# Returning ['Block10', 'Block11']
# Checking pObjs of be to modify pyramid
#   vPrep: on Feature: table
#
# Resolving object: table
# Building concept to search KB for table
# Looking for an ?x that matches:
#       ['inst', '?x', 'table']
#       ['material', '?x', 'metal']
# Found reference in KB: Table1
# Returning ['Table1']
# table resolved to Table1
# Done with prepositions for: pyramid
# Checking features to modify ['Block10', 'Block11']
# Checking features to define ['Block10', 'Block11']
#
# Long Term Memory Category: {'pyramid': {'referenced': ['Block10', 'Block11']}, 'table': {'referenced': ['Table1']}}
# .
# Processing sentence: The pyramids are on the metal table
#
#
# ****************************
#
# The	 	STEM: the 	POS: DET 	REL: det 	HEADER: pyramids 	Children: []
# pyramids 	STEM: pyramid 	POS: NOUN 	REL: nsubj 	HEADER: are 	Children: ['the']
# are	 	STEM: be 	POS: VERB 	REL: ROOT 	HEADER: are 	Children: ['pyramid', 'on']
# on	 	STEM: on 	POS: ADP 	REL: prep 	HEADER: are 	Children: ['table']
# the	 	STEM: the 	POS: DET 	REL: det 	HEADER: table 	Children: []
# metal	 	STEM: metal 	POS: NOUN 	REL: compound 	HEADER: table 	Children: []
# table	 	STEM: table 	POS: NOUN 	REL: pobj 	HEADER: on 	Children: ['the', 'metal']
#
# Sentence is an instance of: S:Feature
# Stubbed out version of buildFeatureStatement
#
# Resolving object: pyramid
# Building concept to search KB for pyramid
# Looking for an ?x that matches:
#       ['inst', '?x', 'pyramid']
# Found reference in KB:
# Returning ['Block10', 'Block11']
# Checking pObjs of be to modify pyramid
#   vPrep: on Feature: table
#
# Resolving object: table
# Building concept to search KB for table
# Looking for an ?x that matches:
#       ['inst', '?x', 'table']
#       ['material', '?x', 'metal']
# Found reference in KB: Table1
# Returning ['Table1']
# table resolved to Table1
# Done with prepositions for: pyramid
# Checking features to modify ['Block10', 'Block11']
# Checking features to define ['Block10', 'Block11']
#
# Long Term Memory Category: {'pyramid': {'referenced': ['Block10', 'Block11']}, 'table': {'referenced': ['Table1']}}
# .
# ----------------------------------------------------------------------
# Ran 9 tests in 13.359s
#
# OK
